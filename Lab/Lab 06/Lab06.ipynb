# %%
import random # Importing library to use random()

items = ['Feroro Rocher','Doritos','Croissant','Thumbs Up','Ice-Cream','Lays','Kurkure','Frooty','Wafer Sticks','Peanuts'] #Items List
qty = [5,1,10,2,6,9,7,3,4,8] #Qty List
price = [500,90,200,70,100,50,30,15,60,120] #Price List

i = 1 #initial value for i i.e iteration factor

while i<=100: # to get random values for eavh list 100 times
    r1 = random.randint(0,9) #r1 to store the randomly generated value used as an index value for Items List
    r2 = random.randint(0,9) #r2 to store the randomly generated value used as an index value for Qty List
    r3 = random.randint(0,9) #r3 to store the randomly generated value used as an index value for Price List

    # Printing all the random values
    print('Random Index from Items List',r1,'\n')   
    print('Random Index from Qty List',r2,'\n')
    print('Random Index from Price List',r3,'\n')

    item = items[r1] #item to store the element at r1 index in items list
    qut = qty[r2] #qt to store the element at r2 index in qty list
    pri = price[r3] #pr to store the element at r3 index in price list

    quan = str(qut) #converting qty to string to enable writing it to the file
    cost = str(pri) #converting unit price to string to enable writing it to the file
    comm = item+','+quan+','+cost #conactenating all three to get a combination
    print(comm,'\n')
    
    file = open('23122015.csv','a+') # Opening the csv file in append mode
    file.write(comm) #Writing the combination formed to the csv file
    file.write('\n') 
    file.close() #Closing the file

    i = i + 1 #Next iteration
# Out:
# Random Index from Items List 9
#
# Random Index from Qty List 6
#
# Random Index from Price List 4
#
# Peanuts,7,100
#
# Random Index from Items List 9
#
# Random Index from Qty List 2
#
# Random Index from Price List 2
#
# Peanuts,10,200
#
# Random Index from Items List 6
#
# Random Index from Qty List 9
#
# Random Index from Price List 7
#
# Kurkure,8,15
#
# Random Index from Items List 0
#
# Random Index from Qty List 1
#
# Random Index from Price List 2
#
# Feroro Rocher,1,200
#
# Random Index from Items List 2
#
# Random Index from Qty List 0
#
# Random Index from Price List 4
#
# Croissant,5,100
#
# Random Index from Items List 3
#
# Random Index from Qty List 1
#
# Random Index from Price List 9
#
# Thumbs Up,1,120
#
# Random Index from Items List 3
#
# Random Index from Qty List 5
#
# Random Index from Price List 5
#
# Thumbs Up,9,50
#
# Random Index from Items List 6
#
# Random Index from Qty List 0
#
# Random Index from Price List 5
#
# Kurkure,5,50
#
# Random Index from Items List 2
#
# Random Index from Qty List 2
#
# Random Index from Price List 2
#
# Croissant,10,200
#
# Random Index from Items List 7
#
# Random Index from Qty List 4
#
# Random Index from Price List 0
#
# Frooty,6,500
#
# Random Index from Items List 6
#
# Random Index from Qty List 2
#
# Random Index from Price List 6
#
# Kurkure,10,30
#
# Random Index from Items List 4
#
# Random Index from Qty List 9
#
# Random Index from Price List 0
#
# Ice-Cream,8,500
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 9
#
# Kurkure,4,120
#
# Random Index from Items List 3
#
# Random Index from Qty List 0
#
# Random Index from Price List 6
#
# Thumbs Up,5,30
#
# Random Index from Items List 9
#
# Random Index from Qty List 0
#
# Random Index from Price List 6
#
# Peanuts,5,30
#
# Random Index from Items List 5
#
# Random Index from Qty List 0
#
# Random Index from Price List 4
#
# Lays,5,100
#
# Random Index from Items List 9
#
# Random Index from Qty List 5
#
# Random Index from Price List 8
#
# Peanuts,9,60
#
# Random Index from Items List 0
#
# Random Index from Qty List 3
#
# Random Index from Price List 6
#
# Feroro Rocher,2,30
#
# Random Index from Items List 0
#
# Random Index from Qty List 2
#
# Random Index from Price List 4
#
# Feroro Rocher,10,100
#
# Random Index from Items List 8
#
# Random Index from Qty List 6
#
# Random Index from Price List 6
#
# Wafer Sticks,7,30
#
# Random Index from Items List 9
#
# Random Index from Qty List 2
#
# Random Index from Price List 3
#
# Peanuts,10,70
#
# Random Index from Items List 3
#
# Random Index from Qty List 9
#
# Random Index from Price List 4
#
# Thumbs Up,8,100
#
# Random Index from Items List 3
#
# Random Index from Qty List 5
#
# Random Index from Price List 7
#
# Thumbs Up,9,15
#
# Random Index from Items List 5
#
# Random Index from Qty List 7
#
# Random Index from Price List 2
#
# Lays,3,200
#
# Random Index from Items List 4
#
# Random Index from Qty List 8
#
# Random Index from Price List 2
#
# Ice-Cream,4,200
#
# Random Index from Items List 2
#
# Random Index from Qty List 7
#
# Random Index from Price List 8
#
# Croissant,3,60
#
# Random Index from Items List 6
#
# Random Index from Qty List 1
#
# Random Index from Price List 4
#
# Kurkure,1,100
#
# Random Index from Items List 2
#
# Random Index from Qty List 2
#
# Random Index from Price List 6
#
# Croissant,10,30
#
# Random Index from Items List 7
#
# Random Index from Qty List 2
#
# Random Index from Price List 9
#
# Frooty,10,120
#
# Random Index from Items List 5
#
# Random Index from Qty List 5
#
# Random Index from Price List 4
#
# Lays,9,100
#
# Random Index from Items List 9
#
# Random Index from Qty List 0
#
# Random Index from Price List 0
#
# Peanuts,5,500
#
# Random Index from Items List 9
#
# Random Index from Qty List 7
#
# Random Index from Price List 2
#
# Peanuts,3,200
#
# Random Index from Items List 6
#
# Random Index from Qty List 7
#
# Random Index from Price List 4
#
# Kurkure,3,100
#
# Random Index from Items List 9
#
# Random Index from Qty List 1
#
# Random Index from Price List 5
#
# Peanuts,1,50
#
# Random Index from Items List 2
#
# Random Index from Qty List 2
#
# Random Index from Price List 6
#
# Croissant,10,30
#
# Random Index from Items List 4
#
# Random Index from Qty List 8
#
# Random Index from Price List 6
#
# Ice-Cream,4,30
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 9
#
# Kurkure,4,120
#
# Random Index from Items List 1
#
# Random Index from Qty List 8
#
# Random Index from Price List 8
#
# Doritos,4,60
#
# Random Index from Items List 8
#
# Random Index from Qty List 2
#
# Random Index from Price List 2
#
# Wafer Sticks,10,200
#
# Random Index from Items List 6
#
# Random Index from Qty List 3
#
# Random Index from Price List 0
#
# Kurkure,2,500
#
# Random Index from Items List 8
#
# Random Index from Qty List 4
#
# Random Index from Price List 3
#
# Wafer Sticks,6,70
#
# Random Index from Items List 0
#
# Random Index from Qty List 0
#
# Random Index from Price List 1
#
# Feroro Rocher,5,90
#
# Random Index from Items List 2
#
# Random Index from Qty List 8
#
# Random Index from Price List 1
#
# Croissant,4,90
#
# Random Index from Items List 5
#
# Random Index from Qty List 4
#
# Random Index from Price List 0
#
# Lays,6,500
#
# Random Index from Items List 6
#
# Random Index from Qty List 4
#
# Random Index from Price List 0
#
# Kurkure,6,500
#
# Random Index from Items List 6
#
# Random Index from Qty List 5
#
# Random Index from Price List 0
#
# Kurkure,9,500
#
# Random Index from Items List 1
#
# Random Index from Qty List 7
#
# Random Index from Price List 9
#
# Doritos,3,120
#
# Random Index from Items List 7
#
# Random Index from Qty List 7
#
# Random Index from Price List 9
#
# Frooty,3,120
#
# Random Index from Items List 0
#
# Random Index from Qty List 0
#
# Random Index from Price List 0
#
# Feroro Rocher,5,500
#
# Random Index from Items List 2
#
# Random Index from Qty List 3
#
# Random Index from Price List 3
#
# Croissant,2,70
#
# Random Index from Items List 2
#
# Random Index from Qty List 4
#
# Random Index from Price List 9
#
# Croissant,6,120
#
# Random Index from Items List 3
#
# Random Index from Qty List 5
#
# Random Index from Price List 7
#
# Thumbs Up,9,15
#
# Random Index from Items List 8
#
# Random Index from Qty List 3
#
# Random Index from Price List 2
#
# Wafer Sticks,2,200
#
# Random Index from Items List 1
#
# Random Index from Qty List 5
#
# Random Index from Price List 0
#
# Doritos,9,500
#
# Random Index from Items List 0
#
# Random Index from Qty List 4
#
# Random Index from Price List 0
#
# Feroro Rocher,6,500
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 9
#
# Kurkure,4,120
#
# Random Index from Items List 6
#
# Random Index from Qty List 2
#
# Random Index from Price List 2
#
# Kurkure,10,200
#
# Random Index from Items List 8
#
# Random Index from Qty List 7
#
# Random Index from Price List 3
#
# Wafer Sticks,3,70
#
# Random Index from Items List 0
#
# Random Index from Qty List 9
#
# Random Index from Price List 7
#
# Feroro Rocher,8,15
#
# Random Index from Items List 8
#
# Random Index from Qty List 6
#
# Random Index from Price List 0
#
# Wafer Sticks,7,500
#
# Random Index from Items List 2
#
# Random Index from Qty List 6
#
# Random Index from Price List 0
#
# Croissant,7,500
#
# Random Index from Items List 7
#
# Random Index from Qty List 1
#
# Random Index from Price List 7
#
# Frooty,1,15
#
# Random Index from Items List 4
#
# Random Index from Qty List 1
#
# Random Index from Price List 5
#
# Ice-Cream,1,50
#
# Random Index from Items List 1
#
# Random Index from Qty List 4
#
# Random Index from Price List 9
#
# Doritos,6,120
#
# Random Index from Items List 7
#
# Random Index from Qty List 4
#
# Random Index from Price List 9
#
# Frooty,6,120
#
# Random Index from Items List 0
#
# Random Index from Qty List 7
#
# Random Index from Price List 1
#
# Feroro Rocher,3,90
#
# Random Index from Items List 3
#
# Random Index from Qty List 7
#
# Random Index from Price List 5
#
# Thumbs Up,3,50
#
# Random Index from Items List 7
#
# Random Index from Qty List 6
#
# Random Index from Price List 3
#
# Frooty,7,70
#
# Random Index from Items List 6
#
# Random Index from Qty List 7
#
# Random Index from Price List 6
#
# Kurkure,3,30
#
# Random Index from Items List 2
#
# Random Index from Qty List 4
#
# Random Index from Price List 8
#
# Croissant,6,60
#
# Random Index from Items List 9
#
# Random Index from Qty List 1
#
# Random Index from Price List 9
#
# Peanuts,1,120
#
# Random Index from Items List 8
#
# Random Index from Qty List 0
#
# Random Index from Price List 3
#
# Wafer Sticks,5,70
#
# Random Index from Items List 0
#
# Random Index from Qty List 1
#
# Random Index from Price List 4
#
# Feroro Rocher,1,100
#
# Random Index from Items List 0
#
# Random Index from Qty List 9
#
# Random Index from Price List 4
#
# Feroro Rocher,8,100
#
# Random Index from Items List 7
#
# Random Index from Qty List 6
#
# Random Index from Price List 4
#
# Frooty,7,100
#
# Random Index from Items List 5
#
# Random Index from Qty List 1
#
# Random Index from Price List 0
#
# Lays,1,500
#
# Random Index from Items List 7
#
# Random Index from Qty List 0
#
# Random Index from Price List 5
#
# Frooty,5,50
#
# Random Index from Items List 7
#
# Random Index from Qty List 6
#
# Random Index from Price List 2
#
# Frooty,7,200
#
# Random Index from Items List 4
#
# Random Index from Qty List 0
#
# Random Index from Price List 7
#
# Ice-Cream,5,15
#
# Random Index from Items List 8
#
# Random Index from Qty List 2
#
# Random Index from Price List 5
#
# Wafer Sticks,10,50
#
# Random Index from Items List 7
#
# Random Index from Qty List 6
#
# Random Index from Price List 5
#
# Frooty,7,50
#
# Random Index from Items List 7
#
# Random Index from Qty List 2
#
# Random Index from Price List 4
#
# Frooty,10,100
#
# Random Index from Items List 7
#
# Random Index from Qty List 4
#
# Random Index from Price List 0
#
# Frooty,6,500
#
# Random Index from Items List 1
#
# Random Index from Qty List 0
#
# Random Index from Price List 7
#
# Doritos,5,15
#
# Random Index from Items List 2
#
# Random Index from Qty List 4
#
# Random Index from Price List 3
#
# Croissant,6,70
#
# Random Index from Items List 3
#
# Random Index from Qty List 4
#
# Random Index from Price List 1
#
# Thumbs Up,6,90
#
# Random Index from Items List 4
#
# Random Index from Qty List 5
#
# Random Index from Price List 2
#
# Ice-Cream,9,200
#
# Random Index from Items List 9
#
# Random Index from Qty List 4
#
# Random Index from Price List 1
#
# Peanuts,6,90
#
# Random Index from Items List 8
#
# Random Index from Qty List 5
#
# Random Index from Price List 4
#
# Wafer Sticks,9,100
#
# Random Index from Items List 9
#
# Random Index from Qty List 5
#
# Random Index from Price List 6
#
# Peanuts,9,30
#
# Random Index from Items List 7
#
# Random Index from Qty List 4
#
# Random Index from Price List 4
#
# Frooty,6,100
#
# Random Index from Items List 5
#
# Random Index from Qty List 9
#
# Random Index from Price List 7
#
# Lays,8,15
#
# Random Index from Items List 6
#
# Random Index from Qty List 9
#
# Random Index from Price List 2
#
# Kurkure,8,200
#
# Random Index from Items List 7
#
# Random Index from Qty List 8
#
# Random Index from Price List 5
#
# Frooty,4,50
#
# Random Index from Items List 3
#
# Random Index from Qty List 8
#
# Random Index from Price List 2
#
# Thumbs Up,4,200
#
# Random Index from Items List 6
#
# Random Index from Qty List 8
#
# Random Index from Price List 3
#
# Kurkure,4,70
#
# Random Index from Items List 2
#
# Random Index from Qty List 3
#
# Random Index from Price List 4
#
# Croissant,2,100
#
# Random Index from Items List 2
#
# Random Index from Qty List 6
#
# Random Index from Price List 3
#
# Croissant,7,70
#
# Random Index from Items List 8
#
# Random Index from Qty List 5
#
# Random Index from Price List 5
#
# Wafer Sticks,9,50
#
# Random Index from Items List 2
#
# Random Index from Qty List 3
#
# Random Index from Price List 0
#
# Croissant,2,500
